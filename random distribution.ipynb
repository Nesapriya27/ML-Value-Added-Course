# %%
from numpy import random
x=random.rand()
print(x)
# Out:
# 0.6790088745590037

# %%
x=random.randint(50)
print(x)
x=random.randint(50,size=10)
# Out:
# 40

# %%
x=random.randint(50,size=(3,3))
print(x)
# Out:
# [[35 49 18]
#  [45  2 11]
#  [24 42 23]]

# %%
x=random.rand(10)
print(x)
# Out:
# [0.26774444 0.87853971 0.5888236  0.43420176 0.53286097 0.31238643
#  0.09588479 0.42512216 0.64785206 0.22699598]

# %%
x=random.choice([5,8,12,9,0])
print(x)
# Out:
# 9

# %%
x=random.choice([5,8,12,9,0],size=(3,3))
print(x)
# Out:
# [[ 0  9 12]
#  [ 5 12  0]
#  [12  0  9]]

# %%
#Permutation

It has two methods:

Shuffle-make changes in the original array
Permutation-it returns a new array and leaves the original array as it is.

# %%
from numpy import random
import numpy as np
a=np.array([1,2,3,4,5])
random.shuffle(a)
print(a)
# Out:
# [4 5 3 2 1]

# %%
b=random.permutation(a)
print(b)
# Out:
# [5 4 3 2 1]

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sb
sb.distplot([10,20,30,40,50,60])
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12492\3028358820.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot([10,20,30,40,50,60])

# %%
sb.distplot([10,20,30,40,50,60],hist=False)
plt.show
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12492\3349966101.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot([10,20,30,40,50,60],hist=False)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
##Normal distribution or Gaussian distribution
#random.normal() is used for normal distribution
#It supports 3 parameters
  #LOC-Mean(peak value of the curve)
  #Scale-SD(Flag section)
  #size-The shape of the resultant array

# %%
x=random.normal(size=5)
print(x)
# Out:
# [ 0.08807782 -1.85361056 -0.71059003 -0.32979204  1.23830628]

# %%
x=random.normal(size=(3,2))
print(x)
# Out:
# [[-0.27312755  0.09654701]
#  [ 0.54142595  1.38704849]
#  [-1.40160653  0.4905365 ]]

# %%
x=random.normal(loc=10,scale=5,size=500)
sb.distplot(x,hist=False)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12492\2111796339.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(x,hist=False)
